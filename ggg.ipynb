# %%
import numpy as np

# %%
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (3,)

# %%
arr2 = np.array([[1,2],[3,4]])
print(arr2)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr2.shape
# Out:
# (2, 2)

# %%
arr3=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(arr3)
print(arr3.shape)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# (2, 2, 2)

# %%
array = np.array([1,2,3,])
print(array*2)
# Out:
# [2 4 6]

# %%
py_list = [1,2,3]
print(py_list*2)
# Out:
# [1, 2, 3, 1, 2, 3]
